# %% [markdown]
# # Explorations

# %%
from backend.connect_to_api import ResRobot

resrobot = ResRobot()

resrobot.access_id_from_location("Umeå")
# Out:
# Name                                     extId        Latitude     Longitude
# --------------------------------------------------------------------------------
# UMEÅ                                     740098065    63.830064    20.26681
# Umeå Centralstation                      740000190    63.830064    20.26681
# Umeå Busstation                          740020461    63.829983    20.264742
# Umeå Östra station                       740001581    63.817659    20.293454
# Umeå Vasaplan                            740020116    63.826136    20.267619
# Umeå Airport                             740025159    63.793451    20.291908
# Umeå Ålidhem centrum                     740023156    63.812175    20.316071
# Umeå Ålidhöjd                            740045439    63.816185    20.314713
# Umeå Älvans väg                          740045410    63.810584    20.337798
# Umeå Alviksgränd                         740045280    63.796525    20.284797

# %%
from backend.connect_to_api import ResRobot
resrobot = ResRobot()

latitude = 57.708895  # Example: Göteborg (Gothenburg)
longitude = 11.973479
max_stops = 10

nearby_stops = resrobot.nearby_stops(latitude, longitude, max_results=max_stops)
# Out:
# Stop Name                                Stop ID    Latitude     Longitude    Distance   Transport Types
# --------------------------------------------------------------------------------------------------------------
# Göteborg Centralstation                  740000002  57.708895    11.973479    0          ['2', '4', '16', '128']
# Göteborg Centralst Drottningt            740030117  57.707898    11.97374     112        ['64', '128']
# Göteborg Åkareplatsen                    740020490  57.708329    11.975942    159        ['8', '128']
# Göteborg Nordstan                        740015585  57.709246    11.970791    164        ['64', '128']
# Göteborg Nils Ericsonterminal            740020483  57.710271    11.971852    180        ['8', '128']
# Göteborg Polhemsplatsen                  740059478  57.70832     11.977317    236        ['128']
# Göteborg Brunnsparken                    740020752  57.706945    11.967843    399        ['64', '128']
# Göteborg Lilla Bommen                    740016360  57.709552    11.966036    448        ['64', '128']
# Lilla Bommens Hamn (Göteborg kn)         740059396  57.711817    11.966036    548        ['256']
# Operan (Göteborg kn)                     740074272  57.710576    11.964265    578        ['128']

# %%
import requests
import os
from dotenv import load_dotenv

# Load API key from .env file (if applicable)
load_dotenv()
API_KEY = os.getenv("API_KEY")

# Set test coordinates (Göteborg / Gothenburg)
latitude = 57.708895
longitude = 11.973479

# API endpoint
url = "https://api.resrobot.se/v2.1/location.nearbystops"

# Query parameters
params = {
    "originCoordLat": latitude,
    "originCoordLong": longitude,
    "format": "json",
    "accessId": API_KEY  # Use the API key from the .env file
}

# Send request
try:
    response = requests.get(url, params=params)
    response.raise_for_status()  # Raise an error for bad responses
    data = response.json()

    # Print raw JSON response
    print("✅ API Response:")
    print(data)

except requests.exceptions.RequestException as err:
    print(f"❌ Error: {err}")
# Out:
# ✅ API Response:
# {'stopLocationOrCoordLocation': [{'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '2'}, {'icon': {'res': 'prod_gen'}, 'cls': '4'}, {'icon': {'res': 'prod_gen'}, 'cls': '16'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@', 'extId': '740000002', 'name': 'Göteborg Centralstation', 'lon': 11.973479, 'lat': 57.708895, 'weight': 9815, 'dist': 0, 'products': 150, 'minimumChangeDuration': 'PT15M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '64'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Centralst Drottningt@X=11973740@Y=57707898@U=1@L=740030117@', 'extId': '740030117', 'name': 'Göteborg Centralst Drottningt', 'lon': 11.97374, 'lat': 57.707898, 'weight': 4608, 'dist': 112, 'products': 192, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '8'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Åkareplatsen@X=11975942@Y=57708329@U=1@L=740020490@', 'extId': '740020490', 'name': 'Göteborg Åkareplatsen', 'lon': 11.975942, 'lat': 57.708329, 'weight': 550, 'dist': 159, 'products': 136, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '64'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@U=1@L=740015585@', 'extId': '740015585', 'name': 'Göteborg Nordstan', 'lon': 11.970791, 'lat': 57.709246, 'weight': 2439, 'dist': 164, 'products': 192, 'minimumChangeDuration': 'PT3M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '8'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Nils Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@', 'extId': '740020483', 'name': 'Göteborg Nils Ericsonterminal', 'lon': 11.971852, 'lat': 57.710271, 'weight': 1758, 'dist': 180, 'products': 136, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=57708320@U=1@L=740059478@', 'extId': '740059478', 'name': 'Göteborg Polhemsplatsen', 'lon': 11.977317, 'lat': 57.70832, 'weight': 533, 'dist': 236, 'products': 128, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '64'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Brunnsparken@X=11967843@Y=57706945@U=1@L=740020752@', 'extId': '740020752', 'name': 'Göteborg Brunnsparken', 'lon': 11.967843, 'lat': 57.706945, 'weight': 4608, 'dist': 399, 'products': 192, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '64'}, {'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Göteborg Lilla Bommen@X=11966036@Y=57709552@U=1@L=740016360@', 'extId': '740016360', 'name': 'Göteborg Lilla Bommen', 'lon': 11.966036, 'lat': 57.709552, 'weight': 2439, 'dist': 448, 'products': 192, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '256'}], 'timezoneOffset': 60, 'id': 'A=1@O=Lilla Bommens Hamn (Göteborg kn)@X=11966036@Y=57711817@U=1@L=740059396@', 'extId': '740059396', 'name': 'Lilla Bommens Hamn (Göteborg kn)', 'lon': 11.966036, 'lat': 57.711817, 'weight': 155, 'dist': 548, 'products': 256, 'minimumChangeDuration': 'PT5M'}}, {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '128'}], 'timezoneOffset': 60, 'id': 'A=1@O=Operan (Göteborg kn)@X=11964265@Y=57710576@U=1@L=740074272@', 'extId': '740074272', 'name': 'Operan (Göteborg kn)', 'lon': 11.964265, 'lat': 57.710576, 'weight': 533, 'dist': 578, 'products': 128, 'minimumChangeDuration': 'PT5M'}}], 'Technica ...

# %%
resrobot.access_id_from_location("Göteborg")
# Out:
# Name                                               extId
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
umea_id = 740000190
gothenburg_id = 740000002

trips = resrobot.trips(umea_id, gothenburg_id)

len(trips["Trip"])
# Out:
# 8

# %%
trips["Trip"][2]["LegList"]
# Out:
# {'Leg': [{'Origin': {'name': 'Umeå Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#     'extId': '740000190',
#     'lon': 20.26681,
#     'lat': 63.830064,
#     'routeIdx': 7,
#     'prognosisType': 'PROGNOSED',
#     'time': '21:16:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT10M'},
#    'Destination': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 19,
#     'prognosisType': 'PROGNOSED',
#     'time': '07:01:00',
#     'date': '2025-01-13',
#     'minimumChangeDuration': 'PT20M'},
#    'Notes': {'Note': [{'value': 'Endast 2 klass',
#       'key': 'AA',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Endast 2 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Sov- och liggvagn',
#       'key': 'SL',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Sov- och liggvagn'}]},
#    'JourneyDetailRef': {'ref': '1|37717|0|1|12012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Nattåg 91',
#      'internalName': 'Nattåg 91',
#      'displayNumber': '91',
#      'num': '91',
#      'line': '91',
#      'lineId': '1074009100003',
#      'catOut': 'JNT',
#      'catIn': 'JNT',
#      'catCode': '2',
#      'cls': '4',
#      'catOutS': 'JNT',
#      'catOutL': 'Nattåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 7,
#      'routeIdxTo': 19,
#      'matchId': '91;91;23363'}],
#    'Stops': {'Stop': [{'name': 'Umeå Centralstation',
#       'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#       'extId': '740000190',
#       'routeIdx': 7,
#       'lon': 20.26681,
#       'lat': 63.830064,
#       'depTime': '21:16:00',
#       'depDate': '2025-01-12',
#       'depDir': 'Stockholm Centralstation',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Umeå Östra station',
#       'id': 'A=1@O=Umeå Östra station@X=20293454@Y=63817659@U=1@L=740001581@',
#       'extId': '740001581',
#       'routeIdx': 8,
#       'lon': 20.293454,
#       'lat': 63.817659,
#       'depTime': '21:23:00',
#       'depDate': '2025-01-12',
#       'arrTime': '21:22:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Nordmaling Resecentrum/Station (Nordmaling-AC kn)',
#       'id': 'A=1@O=Nordmaling Resecentrum/Station (Nordmaling-AC kn)@X=19486285@Y=63578303@U=1@L=740001583@',
#       'extId': '740001583',
#       'routeIdx': 9,
#       'lon': 19.486285,
#       'lat': 63.578303,
#       'depTime': '21:56:00',
#       'depDate': '2025-01-12',
#       'arrTime': '21:56:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Örnsköldsvik Centralstation',
#       'id': 'A=1@O=Örnsköldsvik Centralstation@X=18704305@Y=63289282@U=1@L=740001570@',
#       'extId': '740001570',
#       'routeIdx': 10,
#       'lon': 18.704305,
#       'lat': 63.289282,
#       'depTime': '22:35:00',
#       'depDate': '2025-01-12',
#       'arrTime': '22:35:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Kramfors station',
#       'id': 'A=1@O=Kramfors station@X=17778182@Y=62929111@U=1@L=740000220@',
#       'extId': '740000220',
#       'routeIdx': 11,
#       'lon': 17.778182,
#       'lat': 62.929111,
#       'depTime': '23:28:00',
#       'depDate': '2025-01-12',
#       'arrTime': '23:28:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Härnösand station',
#       'id': 'A=1@O=Härnösand station@X=17928635@Y=62635182@U=1@L=740000253@',
#       'extId': '740000253',
#       'routeIdx': 12,
#       'lon': 17.928635,
#       'lat': 62.635182,
#       'depTime': '00:07:00',
#       'depDate': '2025-01-13',
#       'arrTime': '00:07:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Sundsvall Centralstation',
#       'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#       'extId': '740000130',
#       'routeIdx': 13,
#       'lon': 17.315633,
#       'lat': 62.386873,
#       'depTime': '01:17:00',
#       'depDate': '2025-01-13',
#       'arrTime': '01:02:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hudiksvall station',
#       'id': 'A=1@O=Hudiksvall station@X=17109034@Y=61724494@U=1@L=740000187@',
#       'extId': '740000187',
#       'routeIdx': 14,
#       'lon': 17.109034,
#       'lat': 61.724494,
#       'depTime': '03:00:00',
#       'depDate': '2025-01-13',
#       'arrTime': '02:56:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Söderhamn station',
#       'id': 'A=1@O=Söderhamn station@X=17035682@Y=61299600@U=1@L=740000154@',
#       'extId': '740000154',
#       'routeIdx': 15,
#       'lon': 17.035682,
#       'lat': 61.2996,
#       'depTime': '03:35:00',
#       'depDate': '2025-01-13',
#       'arrTime': '03:35:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Gävle Centralstation',
#       'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#       'extId': '740000210',
#       'routeIdx': 16,
#       'lon': 17.151221,
#       'lat': 60.676118,
#       'depTime': '04:51:00',
#       'depDate': '2025-01-13',
#       'arrTime': '04:31:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Uppsala Centralstation',
#       'id': 'A=1@O=Uppsala Centralstation@X=17646086@Y=59858531@U=1@L=740000005@',
#       'extId': '740000005',
#       'routeIdx': 17,
#       'lon': 17.646086,
#       'lat': 59.858531,
#       'arrTime': '05:53:00',
#       'arrDate': '2025-01-13',
#       'boarding': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Arlanda Centralstation (Sigtuna kn)',
#       'id': 'A=1@O=Arlanda Centralstation (Sigtuna kn)@X=17929201@Y=59649469@U=1@L=740000556@',
#       'extId': '740000556',
#       'routeIdx': 18,
#       'lon': 17.929201,
#       'lat': 59.649469,
#       'arrTime': '06:35:00',
#       'arrDate': '2025-01-13',
#       'boarding': False,
#       'minimumChangeDuration': 'PT2H'},
#      {'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 19,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '07:01:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT20M'}]},
#    'JourneyDetail': {'ref': '1|37717|0|1|12012025',
#     'dayOfOperation': '2025-01-12'},
#    'id': '0',
#    'idx': 0,
#    'name': 'Nattåg 91',
#    'number': '91',
#    'category': 'JNT',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Stockholm Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT9H45M',
#    'minimumChangeDuration': 'PT20M'},
#   {'Origin': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '08:12:00',
#     'date': '2025-01-13',
#     'minimumChangeDuration': 'PT20M'},
#    'Destination': {'name': 'Göteborg Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#     'extId': '740000002',
#     'lon': 11.973479,
#     'lat': 57.708895,
#     'routeIdx': 3,
#     'prognosisType': 'PROGNOSED',
#     'time': '11:41:00',
#     'date': '2025-01-13',
#     'minimumChangeDuration': 'PT15M'},
#    'Notes': {'Note': [{'value': 'X2000',
#       'key': 'VX',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'X2000'},
#      {'value': 'Mat 1 klass',
#       'key': 'A1',
#       'type': 'A',
#       'routeIdxFrom': 1,
#       'routeIdxTo': 3,
#       'txtN': 'Mat 1 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'WiFi'},
#      {'value': '2 klass lugn',
#       'key': 'BL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '2 klass lugn'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Frukost 1 klass',
#       'key': 'SF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Frukost 1 klass'},
#      {'value': 'Maträtt',
#       'key': 'SM',
#       'type': 'A',
#       'routeIdxFrom': 1,
#       'routeIdxTo': 3,
#       'txtN': 'Maträtt'},
#      {'value': '1 klass med extra komfort',
#       'key': 'SU',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '1 klass med extra komfort'},
#      {'value': 'Kaffebuffé 1 klass',
#       'key': 'SZ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Kaffebuffé 1 klass'}]},
#    'JourneyDetailRef': {'ref': '1|28577|0|1|13012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Snabbtåg 425',
#      'internalName': 'Snabbtåg 425',
#      'displayNumber': '425',
#      'num': '425',
#      'line': '425',
#      'lineId': '1074042500001',
#      'catOut': 'JST',
#      'catIn': 'JST',
#      'catCode': '1',
#      'cls': '2',
#      'catOutS': 'JST',
#      'catOutL': 'Snabbtåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 3,
#      'matchId': '425;425;59149'}],
#    'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 0,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '08:12:00',
#       'depDate': '2025-01-13',
#       'depDir': 'Göteborg Centralstation',
#       'minimumChangeDuration': 'PT20M'},
#      {'name': 'Katrineholm Centralstation',
#       'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#       'extId': '740000166',
#       'routeIdx': 1,
#       'lon': 16.208324,
#       'lat': 58.996591,
#       'depTime': '09:04:00',
#       'depDate': '2025-01-13',
#       'arrTime': '09:03:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Skövde Centralstation',
#       'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#       'extId': '740000008',
#       'routeIdx': 2,
#       'lon': 13.853195,
#       'lat': 58.390898,
#       'depTime': '10:22:00',
#       'depDate': '2025-01-13',
#       'arrTime': '10:22:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Göteborg Centralstation',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'routeIdx': 3,
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '11:41:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT15M'}]},
#    'JourneyDetail': {'ref': '1|28577|0|1|13012025',
#     'dayOfOperation': '2025-01-13'},
#    'id': '1',
#    'idx': 1,
#    'name': 'Snabbtåg 425',
#    'number': '425',
#    'category': 'JST',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Göteborg Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT3H29M'}]}

# %%
import pandas as pd 

# pd.DataFrame(trips["Trip"])
legs = []

for trip in trips.get("Trip"):
    legs.append(trip.get("LegList").get("Leg"))

# Umeå -> Stockholm
legs[0][0]["Origin"], legs[0][0]["Destination"]
# Out:
# ({'name': 'Umeå Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#   'extId': '740000190',
#   'lon': 20.26681,
#   'lat': 63.830064,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '14:20:00',
#   'date': '2025-01-20',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 11,
#   'prognosisType': 'PROGNOSED',
#   'time': '20:37:00',
#   'date': '2025-01-20',
#   'minimumChangeDuration': 'PT20M'})

# %%
# Stockholm -> Göteborg
legs[0][1]["Origin"], legs[0][1]["Destination"]
# Out:
# ({'name': 'Sundsvall Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#   'extId': '740000130',
#   'lon': 17.315633,
#   'lat': 62.386873,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '20:53:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Gävle Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#   'extId': '740000210',
#   'lon': 17.151221,
#   'lat': 60.676118,
#   'routeIdx': 3,
#   'prognosisType': 'PROGNOSED',
#   'time': '23:10:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'})

# %%
next_available_trip = legs[0]
df = pd.DataFrame(next_available_trip)
df
# Out:
#                                               Origin  \
# 0  {'name': 'Umeå Centralstation', 'type': 'ST', ...
# 1  {'name': 'Stockholm Centralstation', 'type': '...
#
#                                          Destination  \
# 0  {'name': 'Stockholm Centralstation', 'type': '...
# 1  {'name': 'Göteborg Centralstation', 'type': 'S...
#
#                                                Notes  \
# 0  {'Note': [{'value': 'SJ3000', 'key': 'V3', 'ty...
# 1  {'Note': [{'value': 'X2000', 'key': 'VX', 'typ...
#
#                    JourneyDetailRef JourneyStatus  \
# 0   {'ref': '1|68485|0|1|20012025'}             P
# 1  {'ref': '1|117328|0|1|20012025'}             P
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Stops  \
# 0  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  {'Stop': [{'name': 'Stockholm Centralstation',...
#
#                                        JourneyDetail id  idx          name  \
# 0  {'ref': '1|68485|0|1|20012025', 'dayOfOperatio...  0    0  Snabbtåg 585
# 1  {'ref': '1|117328|0|1|20012025', 'dayOfOperati...  1    1  Snabbtåg 451
#
#   number category type  reachable waitingState                 direction  \
# 0    585      JST  JNY       True        UNDEF  Stockholm Centralstation
# 1    451      JST  JNY       True        UNDEF   Göteborg Centralstation
#
#   directionFlag duration minimumChangeDuration
# 0             1  PT6H17M                 PT20M
# 1             1  PT3H29M                   NaN

# %%
df_trip = df[["name", "Stops"]]
df_trip
# Out:
#            name                                              Stops
# 0  Snabbtåg 585  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  Snabbtåg 451  {'Stop': [{'name': 'Stockholm Centralstation',...

# %%
df_trip["Stops"]
# Out:
# 0    {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1    {'Stop': [{'name': 'Stockholm Centralstation',...
# Name: Stops, dtype: object

# %%
all_stops = pd.json_normalize(df["Stops"].dropna(), "Stop")
all_stops.head()
# Out:
#                           name  \
# 0          Umeå Centralstation
# 1           Umeå Östra station
# 2  Örnsköldsvik Centralstation
# 3             Kramfors station
# 4            Härnösand station
#
#                                                   id      extId  routeIdx  \
# 0  A=1@O=Umeå Centralstation@X=20266810@Y=6383006...  740000190         0
# 1  A=1@O=Umeå Östra station@X=20293454@Y=63817659...  740001581         1
# 2  A=1@O=Örnsköldsvik Centralstation@X=18704305@Y...  740001570         2
# 3  A=1@O=Kramfors station@X=17778182@Y=62929111@U...  740000220         3
# 4  A=1@O=Härnösand station@X=17928635@Y=62635182@...  740000253         4
#
#          lon        lat depPrognosisType   depTime     depDate  \
# 0  20.266810  63.830064        PROGNOSED  14:20:00  2025-01-20
# 1  20.293454  63.817659              NaN  14:25:00  2025-01-20
# 2  18.704305  63.289282              NaN  15:08:00  2025-01-20
# 3  17.778182  62.929111              NaN  15:44:00  2025-01-20
# 4  17.928635  62.635182              NaN  16:07:00  2025-01-20
#
#                      depDir minimumChangeDuration alighting  \
# 0  Stockholm Centralstation                 PT10M       NaN
# 1                       NaN                 PT10M     False
# 2                       NaN                 PT10M       NaN
# 3                       NaN                 PT10M       NaN
# 4                       NaN                 PT10M       NaN
#
#                                           Notes.Note   arrTime     arrDate  \
# 0                                                NaN       NaN         NaN
# 1  [{'value': 'Stannar endast för påstigande', 'k...       NaN         NaN
# 2                                                NaN  15:08:00  2025-01-20
# 3                                                NaN  15:44:00  2025-01-20
# 4                                                NaN  16:07:00  2025-01-20
#
#   boarding arrPrognosisType
# 0      NaN              NaN
# 1      NaN              NaN
# 2      NaN              NaN
# 3      NaN              NaN
# 4      NaN              NaN

# %%
stops = all_stops[["name", "arrTime", "arrDate", "depTime", "depDate", "lon", "lat"]]
stops
# Out:
#                                    name   arrTime     arrDate   depTime  \
# 0                   Umeå Centralstation       NaN         NaN  14:20:00
# 1                    Umeå Östra station       NaN         NaN  14:25:00
# 2           Örnsköldsvik Centralstation  15:08:00  2025-01-20  15:08:00
# 3                      Kramfors station  15:44:00  2025-01-20  15:44:00
# 4                     Härnösand station  16:07:00  2025-01-20  16:07:00
# 5              Sundsvall Centralstation  16:59:00  2025-01-20  17:04:00
# 6                    Hudiksvall station  18:00:00  2025-01-20  18:00:00
# 7                     Söderhamn station  18:28:00  2025-01-20  18:28:00
# 8                  Gävle Centralstation  19:10:00  2025-01-20  19:14:00
# 9                Uppsala Centralstation  19:59:00  2025-01-20       NaN
# 10  Arlanda Centralstation (Sigtuna kn)  20:19:00  2025-01-20       NaN
# 11             Stockholm Centralstation  20:37:00  2025-01-20       NaN
# 12             Stockholm Centralstation       NaN         NaN  21:12:00
# 13           Katrineholm Centralstation  22:04:00  2025-01-20  22:05:00
# 14                Skövde Centralstation  23:22:00  2025-01-20  23:22:00
# 15              Göteborg Centralstation  00:41:00  2025-01-21       NaN
#
#        depDate        lon        lat
# 0   2025-01-20  20.266810  63.830064
# 1   2025-01-20  20.293454  63.817659
# 2   2025-01-20  18.704305  63.289282
# 3   2025-01-20  17.778182  62.929111
# 4   2025-01-20  17.928635  62.635182
# 5   2025-01-20  17.315633  62.386873
# 6   2025-01-20  17.109034  61.724494
# 7   2025-01-20  17.035682  61.299600
# 8   2025-01-20  17.151221  60.676118
# 9          NaN  17.646086  59.858531
# 10         NaN  17.929201  59.649469
# 11         NaN  18.058151  59.330136
# 12  2025-01-20  18.058151  59.330136
# 13  2025-01-20  16.208324  58.996591
# 14  2025-01-20  13.853195  58.390898
# 15         NaN  11.973479  57.708895

# %%
stops = stops.drop_duplicates(subset="name").reset_index(drop=True)
stops
# Out:
#                                    name   arrTime     arrDate   depTime  \
# 0                   Umeå Centralstation       NaN         NaN  14:20:00
# 1                    Umeå Östra station       NaN         NaN  14:25:00
# 2           Örnsköldsvik Centralstation  15:08:00  2025-01-20  15:08:00
# 3                      Kramfors station  15:44:00  2025-01-20  15:44:00
# 4                     Härnösand station  16:07:00  2025-01-20  16:07:00
# 5              Sundsvall Centralstation  16:59:00  2025-01-20  17:04:00
# 6                    Hudiksvall station  18:00:00  2025-01-20  18:00:00
# 7                     Söderhamn station  18:28:00  2025-01-20  18:28:00
# 8                  Gävle Centralstation  19:10:00  2025-01-20  19:14:00
# 9                Uppsala Centralstation  19:59:00  2025-01-20       NaN
# 10  Arlanda Centralstation (Sigtuna kn)  20:19:00  2025-01-20       NaN
# 11             Stockholm Centralstation  20:37:00  2025-01-20       NaN
# 12           Katrineholm Centralstation  22:04:00  2025-01-20  22:05:00
# 13                Skövde Centralstation  23:22:00  2025-01-20  23:22:00
# 14              Göteborg Centralstation  00:41:00  2025-01-21       NaN
#
#        depDate        lon        lat
# 0   2025-01-20  20.266810  63.830064
# 1   2025-01-20  20.293454  63.817659
# 2   2025-01-20  18.704305  63.289282
# 3   2025-01-20  17.778182  62.929111
# 4   2025-01-20  17.928635  62.635182
# 5   2025-01-20  17.315633  62.386873
# 6   2025-01-20  17.109034  61.724494
# 7   2025-01-20  17.035682  61.299600
# 8   2025-01-20  17.151221  60.676118
# 9          NaN  17.646086  59.858531
# 10         NaN  17.929201  59.649469
# 11         NaN  18.058151  59.330136
# 12  2025-01-20  16.208324  58.996591
# 13  2025-01-20  13.853195  58.390898
# 14         NaN  11.973479  57.708895

# %%
stops["time"] = stops["arrTime"].fillna(stops["depTime"])
stops["date"] = stops["arrDate"].fillna(stops["depDate"])

# %%
import folium

geographical_map = folium.Map(
    location=[stops["lat"].mean(), stops["lon"].mean()], zoom_start=5
)

for _, row in stops.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"{row['name']}<br>{row['time']}<br>{row['date']}",
    ).add_to(geographical_map)

geographical_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3373d1c7aa67c2c66c705896a9500af1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3373d1c7aa67c2c66c705896a9500af1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3373d1c7aa67c2c66c705896a9500af1 = L.map(
#                 &quot;map_3373d1c7aa67c2c66c705896a9500af1&quot;,
#                 {
#                     center: [61.69235985, 17.232072199999998],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7697bba6949d22500b5516a774d2a11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7697bba6949d22500b5516a774d2a11.addTo(map_3373d1c7aa67c2c66c705896a9500af1);
#
#
#             var marker_97232751b59abb5e8b983324b60653ca = L.marker(
#                 [63.830064, 20.26681],
#                 {
# }
#             ).addTo(map_3373d1c7aa67c2c66c705896a9500af1);
#
#
#         var popup_d417e4e682971b0cf01d23c328d1a547 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a59b0fd30372907d7292d56d2fda064 = $(`&lt;div id=&quot;html_4a59b0fd30372907d7292d56d2fda064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Centralstation&lt;br&gt;17:37:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_d417e4e682971b0cf01d23c328d1a547.setContent(html_4a59b0fd30372907d7292d56d2fda064);
#
#
#
#         marker_97232751b59abb5e8b983324b60653ca.bindPopup(popup_d417e4e682971b0cf01d23c328d1a547)
#         ;
#
#
#
#
#             var marker_e0910008d4f913179ce4499c46f0d724 = L.marker(
#                 [63.817659, 20.293454],
#                 {
# }
#             ).addTo(map_3373d1c7aa67c2c66c705896a9500af1);
#
#
#         var popup_091246aaca2c650448994d7514f4eb8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_330b577e501383840343133391816f2e = $(`&lt;div id=&quot;html_330b577e501383840343133391816f2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Östra station&lt;br&gt;17:42:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_091246aaca2c650448994d7514f4eb8c.setContent(html_330b577e501383840343133391816f2e);
#
#
#
#         marker_e0910008d4f913179ce4499c46f0d724.bindPopup(popup_091246aaca2c650448994d7514f4eb8c)
#         ;
#
#
#
#
#             var marker_5a50ace58e78137179c50a50ec612602 = L.marker(
#                 [63.632661, 19.908464],
#                 {
# }
#             ).addTo(map_3373d1c7aa67c2c66c705896a9500af1);
#
#
#         var popup_17f9e3d2d53619d3089224eb50560573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_288af00b55af128ca88de54a3f1cc07b = $(`&lt;div id=&quot;html_288af00b55af128ca88de54a3f1cc07b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hörnefors Resecentrum/Station (Umeå kn)&lt;br&gt;17:56:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_17f9e3d2d53619d3089224eb50560573.setContent(html_288af00b55af128ca88de54a3f1cc07b);
#
#
#
#         marker_5a50ace58e78137179c50a50ec612602.bindPopup(popup_17f9e3d2d53619d3089224eb50560573)
#         ;
#
#
#
#
#             var marker_2f1f7437cf14d11c44d8e839188d5417 = L.marker(
#                 [63.578303, 19.486285],
#                 {
# }
#             ).addTo(map_3373d1c7aa67c2c66c705896a9500af1);
#
#
#         var popup_8a114fea298b097f7498e83b3f2bbc62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd406eaaba9bca0dca1ddc4932f0c5a4 = $(`&lt;div id=&quot;html_bd406eaaba9bca0dca1ddc4932f0c5a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nordmaling Resecentrum/Station (Nordmaling-AC kn)&lt;br&gt;18:07:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_8a114fea298b097f7498e83b3f2bbc62.setContent(html_bd406eaaba9bca0dca1ddc4932f0c5a4);
#
#
#
#         marker_2f1f7437cf14d11c44d8e839188d5417.bindPopup(popup_8a114fea298b097f7498e83b3f2bbc62)
#         ;
#
#
#
#
#             var marker_0b259a528f830912a83004621ab94bf4 = L.marker(
#                 [63.343909, 19.155725],
#                 {
# }
#             ).addTo(map_3373d1c7aa67c2c66c705896a9500af1);
#
#
#         var popup_4d3f4ea7a6060cb9498ac9b9ba3dcac7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e81f5906bab89400e412cda2356f463 = $(`&lt;div id=&quot;html_8e81f5906bab89400e412cda2356f463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Husum station (Örnsköldsvik kn)&lt;br&gt;18:22:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_4d3f4ea7a6060cb9498ac9b9ba3dcac7.setContent(html_8e81f5906bab89400e4
